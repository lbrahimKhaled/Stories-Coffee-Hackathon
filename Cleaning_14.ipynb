# %%
import pandas as pd

# Read CSV file
df = pd.read_csv("datasets/rep_s_00014_SMRY.csv", header = 3)

# Preview first 5 rows
df.head()
# Out:
#           Product Desc     Qty Total Price Unnamed: 3 Total Cost Total Cost %  \
# 0  Stories - Bir Hasan     NaN         NaN        NaN        NaN          NaN
# 1            TAKE AWAY     NaN         NaN        NaN        NaN          NaN
# 2            BEVERAGES     NaN         NaN        NaN        NaN          NaN
# 3     COLD BAR SECTION     NaN         NaN        NaN        NaN          NaN
# 4        1 SHOT DECAFE  404.00        0.00        NaN   3,856.85         0.00
#
#   Total Profit Unnamed: 7 Total Profit %  Unnamed: 9
# 0          NaN        NaN            NaN         NaN
# 1          NaN        NaN            NaN         NaN
# 2          NaN        NaN            NaN         NaN
# 3          NaN        NaN            NaN         NaN
# 4    -3,856.85        NaN         100.00         NaN

# %%
# let's see how many empty values in each column there is
useless = []
for col in df.columns:
    nan_count = df[col].isna().sum()
    nan_percent = (nan_count / len(df)) * 100
    print(f"In column '{col}' there are {nan_percent:.2f}% NaN values ({nan_count} empty cells)")
    if nan_percent >= 90:
        useless.append(col)
# Out:
# In column 'Product Desc' there are 0.00% NaN values (0 empty cells)
# In column 'Qty' there are 7.15% NaN values (1042 empty cells)
# In column 'Total Price' there are 7.15% NaN values (1043 empty cells)
# In column 'Unnamed: 3' there are 97.29% NaN values (14186 empty cells)
# In column 'Total Cost' there are 7.15% NaN values (1043 empty cells)
# In column 'Total Cost %' there are 7.15% NaN values (1043 empty cells)
# In column 'Total Profit' there are 7.15% NaN values (1043 empty cells)
# In column 'Unnamed: 7' there are 97.29% NaN values (14186 empty cells)
# In column 'Total Profit %' there are 7.15% NaN values (1042 empty cells)
# In column 'Unnamed: 9' there are 97.29% NaN values (14186 empty cells)

# %%
df.columns
# Out:
# Index(['Product Desc', 'Qty', 'Total Price', 'Unnamed: 3', 'Total Cost',
#        'Total Cost %', 'Total Profit', 'Unnamed: 7', 'Total Profit %',
#        'Unnamed: 9'],
#       dtype='object')

# %%
##cleanup of useless rows (Jan or Product desc)
col0 = df.columns[0]  # first column (should be "Product Desc")

bad_values = {"22-Jan-26", "Product Desc"}

df = df[~df[col0].astype(str).str.strip().isin(bad_values)].reset_index(drop=True)

# %%
#everything above 90% we ll drop completely useless LOL
df = df.drop(columns = useless)

# %%
# we will add a column true if all the important features are NaN else false
df["all_nan"] = df.drop(columns = ['Product Desc']).isna().all(axis=1)

# %%
import re
import pandas as pd
import numpy as np

# -------------------------
# Load your cleaned file
# -------------------------
# df = pd.read_csv("cleaned.csv")
# or if df is already in memory, skip loading.

# REQUIRED columns:
# 'Product Desc', 'Qty', 'Total Price', 'Total Cost', 'Total Cost %', 'Total Profit', 'Total Profit %'
col_desc = "Product Desc"
col_qty  = "Qty"

levels = ["Branch", "Department", "Category", "Division"]
total_pat = re.compile(r"^\s*Total\s+By\s+(Branch|Department|Category|Division)\s*:?\s*$", re.IGNORECASE)

def is_blank(x) -> bool:
    return pd.isna(x) or str(x).strip().lower() in ("", "nan", "none")

def extract_branch_name(s: str) -> str:
    s = str(s).strip()
    if " - " in s:
        return s.split(" - ", 1)[1].strip()
    if "-" in s:
        return s.split("-", 1)[1].strip()
    return s

def choose_open_level(current: dict) -> str:
    for lv in levels:
        if current[lv] is None:
            return lv
    return "Division"  # fallback if file has deeper splits but same "Total By Division" closing

def clear_from(level: str, current: dict):
    idx = levels.index(level)
    for lv in levels[idx:]:
        current[lv] = None

# -------------------------
# Parse & fill hierarchy
# -------------------------
current = {lv: None for lv in levels}

out = {lv: [] for lv in levels}

for _, row in df.iterrows():
    txt_raw = row.get(col_desc, "")
    txt = "" if is_blank(txt_raw) else str(txt_raw).strip()

    # Closing row? "Total By Division:" etc.
    m = total_pat.match(txt)
    if m:
        # include the current hierarchy on the total row itself
        for lv in levels:
            out[lv].append(current[lv])

        closing_level = m.group(1).title()  # Branch/Department/Category/Division
        clear_from(closing_level, current)
        continue

    # Opening row? (Hierarchy headers usually have Qty empty/NaN after cleaning)
    qty_val = row.get(col_qty, np.nan)
    qty_is_nan = pd.isna(qty_val)

    if qty_is_nan and txt:
        open_level = choose_open_level(current)

        if open_level == "Branch":
            current["Branch"] = extract_branch_name(txt)
            current["Department"] = None
            current["Category"] = None
            current["Division"] = None
        elif open_level == "Department":
            current["Department"] = txt
            current["Category"] = None
            current["Division"] = None
        elif open_level == "Category":
            current["Category"] = txt
            current["Division"] = None
        else:  # Division
            current["Division"] = txt

        # tag the opening row with the updated hierarchy
        for lv in levels:
            out[lv].append(current[lv])
        continue

    # Normal/product row: inherit current hierarchy
    for lv in levels:
        out[lv].append(current[lv])

# attach columns
for lv in levels:
    df[lv] = out[lv]

# save if you want
# df.to_csv("cleaned_with_hierarchy.csv", index=False)

df.head(30)
# Out:
#                   Product Desc       Qty Total Price Total Cost Total Cost %  \
# 0          Stories - Bir Hasan       NaN         NaN        NaN          NaN
# 1                    TAKE AWAY       NaN         NaN        NaN          NaN
# 2                    BEVERAGES       NaN         NaN        NaN          NaN
# 3             COLD BAR SECTION       NaN         NaN        NaN          NaN
# 4                1 SHOT DECAFE    404.00        0.00   3,856.85         0.00
# 5                2 SHOT DECAFE    637.00        0.00  12,162.45         0.00
# 6                3 SHOT DECAFE    113.00        0.00   3,236.32         0.00
# 7       ADD BANANA SAUCE LARGE      4.00      266.67     139.97        52.49
# 8      ADD BANANA SAUCE MEDIUM     47.00    1,487.39     822.34        55.29
# 9       ADD BANANA SAUCE SMALL     28.00      893.72     489.91        54.82
# 10         ADD CARAMEL DRIZZLE    700.00   23,370.36   2,349.38        10.05
# 11           ADD CARAMEL LARGE    313.00   10,488.50   2,690.19        25.65
# 12          ADD CARAMEL MEDIUM  1,142.00   37,584.33   8,923.01        23.74
# 13        ADD CARAMEL SF LARGE    236.00    7,889.52   3,097.89        39.27
# 14       ADD CARAMEL SF MEDIUM    851.00   28,513.00   8,378.09        29.38
# 15        ADD CARAMEL SF SMALL    848.00   28,567.21   5,565.71        19.48
# 16           ADD CARAMEL SMALL    552.00   12,662.43   2,875.37        22.71
# 17       ADD CHOCOLATE DRIZZLE    227.00    7,703.96     748.50         9.72
# 18           ADD FULL FAT MILK     20.00        0.00      67.12         0.00
# 19          ADD HAZELNUT LARGE    104.00    3,530.54   1,126.27        31.90
# 20         ADD HAZELNUT MEDIUM    324.00   10,677.66   3,189.78        29.87
# 21          ADD HAZELNUT SMALL    283.00    9,072.88   1,857.42        20.47
# 22            ADD MATCHA LARGE      3.00      186.19     139.62        74.99
# 23           ADD MATCHA MEDIUM      1.00       54.05      37.23        68.88
# 24            ADD MATCHA SMALL      4.00      180.18     111.70        61.99
# 25             ADD MOCHA LARGE     42.00    1,434.74     830.94        57.92
# 26            ADD MOCHA MEDIUM     70.00    2,373.27   1,038.67        43.77
# 27             ADD MOCHA SMALL     25.00      622.25     247.30        39.74
# 28   ADD RASPBERRY SAUCE LARGE     26.00    1,746.67     819.66        46.93
# 29  ADD RASPBERRY SAUCE MEDIUM     69.00    2,303.33   1,087.63        47.22
#
#    Total Profit Total Profit %  all_nan     Branch Department   Category  \
# 0           NaN            NaN     True  Bir Hasan       None       None
# 1           NaN            NaN     True  Bir Hasan  TAKE AWAY       None
# 2           NaN            NaN     True  Bir Hasan  TAKE AWAY  BEVERAGES
# 3           NaN            NaN     True  Bir Hasan  TAKE AWAY  BEVERAGES
# 4     -3,856.85         100.00    False  Bir Hasan  TAKE AWAY  BEVERAGES
# 5    -12,162.45         100.00    False  Bir Hasan  TAKE AWAY  BEVERAGES
# 6     -3,236.32         100.00    False  Bir Hasan  TAKE AWAY  BEVERAGES
# 7        126.69          47.51    False  Bir Hasan  TAKE AWAY  BEVERAGES
# 8        665.04          44.71    False  Bir Hasan  TAKE AWAY  BEVERAGES
# 9        403.82          45.18    False  Bir Hasan  TAKE AWAY  BEVERAGES
# 10    21,020.99          89.95    False  Bir Hasan  TAKE AWAY  BEVERAGES
# 11     7,798.31          74.35    False  Bir Hasan  TAKE AWAY  BEVERAGES
# 12    28,661.32          76.26    False  Bir Hasan  TAKE AWAY  BEVERAGES
# 13     4,791.63          60.73    False  Bir Hasan  TAKE AWAY  BEVERAGES
# 14    20,134.91          70.62    False  Bir Hasan  TAKE AWAY  BEVERAGES
# 15    23,001.50          80.52    False  Bir Hasan  TAKE AWAY  BEVERAGES
# 16     9,787.07          77.29    False  Bir Hasan  TAKE AWAY  BEVERAGES
# 17     6,955.46          90.28    False  Bir Hasan  TAKE AWAY  BEVERAGES
# 18       -67.12         100.00    False  Bir Hasan  TAKE AWAY  BEVERAGES
# 19     2,404.27          68.10    False  Bir Hasan  TAKE AWAY  BEVERAGES
# 20     7,487.88          70.13    False  Bir Hasan  TAKE AWAY  BEVERAGES
# 21     7,215.46          79.53    False  Bir Hasan  TAKE AWAY  BEVERAGES
# 22        46.57          25.01    False  Bir Hasan  TAKE AWAY  BEVERAGES
# 23        16.82          31.12    False  Bir Hasan  TAKE AWAY  BEVERAGES
# 24        68.48          38.01    False  Bir Hasan  TAKE AWAY  BEVERAGES
# 25       603.81          42.08    False  Bir Hasan  TAKE AWAY  BEVERAGES
# 26     1,334.60          56.23    False  Bir Hasan  TAKE AWAY  BEVERAGES
# 27       374.95          60.26    False  Bir Hasan  TAKE AWAY  BEVERAGES
# 28       927.00          53.07    False  Bir Hasan  TAKE AWAY  BEVERAGES
# 29     1,215.70          52.78    False  Bir Hasan  TAKE AWAY  BEVERAGES
#
#             Division
# 0               None
# 1               None
# 2               None
# 3   COLD BAR SECTION
# 4   COLD BAR SECTION
# 5   COLD BAR SECTION
# 6   COLD BAR SECTION
# 7   COLD BAR SECTION
# 8   COLD BAR SECTION
# 9   COLD BAR SECTION
# 10  COLD BAR SECTION
# 11  COLD BAR SECTION
# 12  COLD BAR SECTION
# 13  COLD BAR SECTION
# 14  COLD BAR SECTION
# 15  COLD BAR SECTION
# 16  COLD BAR SECTION
# 17  COLD BAR SECTION
# 18  COLD BAR SECTION
# 19  COLD BAR SECTION
# 20  COLD BAR SECTION
# 21  COLD BAR SECTION
# 22  COLD BAR SECTION
# 23  COLD BAR SECTION
# 24  COLD BAR SECTION
# 25  COLD BAR SECTION
# 26  COLD BAR SECTION
# 27  COLD BAR SECTION
# 28  COLD BAR SECTION
# 29  COLD BAR SECTION

# %%
df["Division"].value_counts()
# Out:
# Division
# COLD BAR SECTION       4451
# FROZEN YOGHURT         2486
# HOT BAR SECTION        2204
# MEDIUM                  567
# GRAB&GO FOOD            566
# COFFEE PASTRY           488
# SANDWICHES              459
# GRAB&GO BEVERAGES       378
# FRENCH PASTRY           337
# CROISSANT               221
# CINNAMON ROLLS          210
# SUBS                    198
# SMALL                   179
# COOKIES                 145
# PLAT DE JOUR            124
# POP UP BEVERAGE          98
# OFFER                    89
# HEALTHY SECTION          81
# LARGE                    39
# LATTE SMALL              32
# SALADS BAR               30
# YOGHURT COMBO SMALL      21
# PIZZA                    15
# CREAM                    14
# 250 ML                   12
# CRUNCH                   10
# 250ML/24                  8
# YOUGHURT                  8
# WRAP                      8
# SPECULOSE LOTUS           6
# CLEMENTINE 330ML/24       5
# BITES                     4
# 330ML/24                  3
# Name: count, dtype: int64

# %% [markdown]
# ### since there are still NaN values but for some rows we will be cleaning up all rows that have all the columns values = NaN

# %%
# then we will drop all the stuff that have all NaN
df = df[~df["all_nan"]]
# for cleanup let's reset the index and drop the last column 
df = df.reset_index(drop = True)
df = df.iloc[:-1]

# %%
## let's retest the NaN test:
# let's see how many empty values in each column there is
useless = []
for col in df.columns:
    nan_count = df[col].isna().sum()
    nan_percent = (nan_count / len(df)) * 100
    print(f"In column '{col}' there are {nan_percent:.2f}% NaN values ({nan_count} empty cells)")
    if nan_percent >= 90:
        useless.append(col)
#0 % NaN = LA3IBBBB
# Out:
# In column 'Product Desc' there are 0.00% NaN values (0 empty cells)
# In column 'Qty' there are 0.00% NaN values (0 empty cells)
# In column 'Total Price' there are 0.00% NaN values (0 empty cells)
# In column 'Total Cost' there are 0.00% NaN values (0 empty cells)
# In column 'Total Cost %' there are 0.00% NaN values (0 empty cells)
# In column 'Total Profit' there are 0.00% NaN values (0 empty cells)
# In column 'Total Profit %' there are 0.00% NaN values (0 empty cells)
# In column 'all_nan' there are 0.00% NaN values (0 empty cells)
# In column 'Branch' there are 0.00% NaN values (0 empty cells)
# In column 'Department' there are 0.19% NaN values (25 empty cells)
# In column 'Category' there are 0.51% NaN values (67 empty cells)
# In column 'Division' there are 1.12% NaN values (147 empty cells)

# %%
df
# Out:
#                   Product Desc        Qty   Total Price  Total Cost  \
# 0                1 SHOT DECAFE     404.00          0.00    3,856.85
# 1                2 SHOT DECAFE     637.00          0.00   12,162.45
# 2                3 SHOT DECAFE     113.00          0.00    3,236.32
# 3       ADD BANANA SAUCE LARGE       4.00        266.67      139.97
# 4      ADD BANANA SAUCE MEDIUM      47.00      1,487.39      822.34
# ...                        ...        ...           ...         ...
# 13138                 ADD TUNA       7.00      1,027.03      334.50
# 13139       Total By Division:      51.00      5,579.58    2,381.77
# 13140       Total By Category:  10,528.50  1,287,075.68  484,453.55
# 13141     Total By Department:  22,252.50  2,818,715.92  844,897.47
# 13142         Total By Branch:  22,261.50  2,819,448.66  845,094.73
#
#       Total Cost %  Total Profit Total Profit %  all_nan          Branch  \
# 0             0.00     -3,856.85         100.00    False       Bir Hasan
# 1             0.00    -12,162.45         100.00    False       Bir Hasan
# 2             0.00     -3,236.32         100.00    False       Bir Hasan
# 3            52.49        126.69          47.51    False       Bir Hasan
# 4            55.29        665.04          44.71    False       Bir Hasan
# ...            ...           ...            ...      ...             ...
# 13138        32.57        692.53          67.43    False  Stories kaslik
# 13139        42.69      3,197.81          57.31    False  Stories kaslik
# 13140        37.64    802,622.12          62.36    False  Stories kaslik
# 13141        29.97  1,973,818.45          70.03    False  Stories kaslik
# 13142        29.97  1,974,353.92          70.03    False  Stories kaslik
#
#       Department   Category          Division
# 0      TAKE AWAY  BEVERAGES  COLD BAR SECTION
# 1      TAKE AWAY  BEVERAGES  COLD BAR SECTION
# 2      TAKE AWAY  BEVERAGES  COLD BAR SECTION
# 3      TAKE AWAY  BEVERAGES  COLD BAR SECTION
# 4      TAKE AWAY  BEVERAGES  COLD BAR SECTION
# ...          ...        ...               ...
# 13138  TAKE AWAY       FOOD              SUBS
# 13139  TAKE AWAY       FOOD              SUBS
# 13140  TAKE AWAY       FOOD              None
# 13141  TAKE AWAY       None              None
# 13142       None       None              None
#
# [13143 rows x 12 columns]
